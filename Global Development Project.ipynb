# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# #### Load the dataset

# %%
data= pd.read_excel("World_development_mesurement.xlsx")
data.head()
# Out:
#    Birth Rate Business Tax Rate  CO2 Emissions       Country  \
# 0       0.020               NaN        87931.0       Algeria
# 1       0.050               NaN         9542.0        Angola
# 2       0.043               NaN         1617.0         Benin
# 3       0.027               NaN         4276.0      Botswana
# 4       0.046               NaN         1041.0  Burkina Faso
#
#    Days to Start Business  Ease of Business  Energy Usage              GDP  \
# 0                     NaN               NaN       26998.0  $54,790,058,957
# 1                     NaN               NaN        7499.0   $9,129,594,819
# 2                     NaN               NaN        1983.0   $2,359,122,303
# 3                     NaN               NaN        1836.0   $5,788,311,645
# 4                     NaN               NaN           NaN   $2,610,959,139
#
#    Health Exp % GDP Health Exp/Capita  ...  Life Expectancy Male  \
# 0             0.035               $60  ...                  67.0
# 1             0.034               $22  ...                  44.0
# 2             0.043               $15  ...                  53.0
# 3             0.047              $152  ...                  49.0
# 4             0.051               $12  ...                  49.0
#
#    Mobile Phone Usage  Number of Records  Population 0-14  Population 15-64  \
# 0                 0.0                  1            0.342             0.619
# 1                 0.0                  1            0.476             0.499
# 2                 0.0                  1            0.454             0.517
# 3                 0.1                  1            0.383             0.587
# 4                 0.0                  1            0.468             0.505
#
#    Population 65+  Population Total  Population Urban  Tourism Inbound  \
# 0           0.039          31719449             0.599     $102,000,000
# 1           0.025          13924930             0.324      $34,000,000
# 2           0.029           6949366             0.383      $77,000,000
# 3           0.029           1755375             0.532     $227,000,000
# 4           0.028          11607944             0.178      $23,000,000
#
#    Tourism Outbound
# 0      $193,000,000
# 1      $146,000,000
# 2       $50,000,000
# 3      $209,000,000
# 4       $30,000,000
#
# [5 rows x 25 columns]

# %%
data.shape
# Out:
# (2704, 25)

# %%
data.columns
# Out:
# Index(['Birth Rate', 'Business Tax Rate', 'CO2 Emissions', 'Country',
#        'Days to Start Business', 'Ease of Business', 'Energy Usage', 'GDP',
#        'Health Exp % GDP', 'Health Exp/Capita', 'Hours to do Tax',
#        'Infant Mortality Rate', 'Internet Usage', 'Lending Interest',
#        'Life Expectancy Female', 'Life Expectancy Male', 'Mobile Phone Usage',
#        'Number of Records', 'Population 0-14', 'Population 15-64',
#        'Population 65+', 'Population Total', 'Population Urban',
#        'Tourism Inbound', 'Tourism Outbound'],
#       dtype='object')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2704 entries, 0 to 2703
# Data columns (total 25 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Birth Rate              2585 non-null   float64
#  1   Business Tax Rate       1423 non-null   object
#  2   CO2 Emissions           2125 non-null   float64
#  3   Country                 2704 non-null   object
#  4   Days to Start Business  1718 non-null   float64
#  5   Ease of Business        185 non-null    float64
#  6   Energy Usage            1785 non-null   float64
#  7   GDP                     2494 non-null   object
#  8   Health Exp % GDP        2395 non-null   float64
#  9   Health Exp/Capita       2395 non-null   object
#  10  Hours to do Tax         1416 non-null   float64
#  11  Infant Mortality Rate   2444 non-null   float64
#  12  Internet Usage          2531 non-null   float64
#  13  Lending Interest        1880 non-null   float64
#  14  Life Expectancy Female  2568 non-null   float64
#  15  Life Expectancy Male    2568 non-null   float64
#  16  Mobile Phone Usage      2537 non-null   float64
#  17  Number of Records       2704 non-null   int64
#  18  Population 0-14         2484 non-null   float64
#  19  Population 15-64        2484 non-null   float64
#  20  Population 65+          2484 non-null   float64
#  21  Population Total        2704 non-null   int64
#  22  Population Urban        2678 non-null   float64
#  23  Tourism Inbound         2336 non-null   object
#  24  Tourism Outbound        2233 non-null   object
# dtypes: float64(17), int64(2), object(6)
# memory usage: 528.3+ KB

# %%
data.describe()
# Out:
#         Birth Rate  CO2 Emissions  Days to Start Business  Ease of Business  \
# count  2585.000000   2.125000e+03             1718.000000        185.000000
# mean      0.022715   1.423071e+05               39.999418         94.875676
# std       0.011338   6.159288e+05               57.318588         54.791906
# min       0.007000   7.000000e+00                1.000000          1.000000
# 25%       0.013000   1.360000e+03               13.000000         48.000000
# 50%       0.020000   8.529000e+03               26.000000         94.000000
# 75%       0.031000   5.910800e+04               45.000000        142.000000
# max       0.053000   8.286892e+06              694.000000        189.000000
#
#        Energy Usage  Health Exp % GDP  Hours to do Tax  Infant Mortality Rate  \
# count  1.785000e+03       2395.000000      1416.000000            2444.000000
# mean   7.723684e+04          0.064170       302.068503               0.032813
# std    2.599239e+05          0.026325       273.299686               0.029968
# min    8.000000e+00          0.008000        12.000000               0.002000
# 25%    3.737000e+03          0.046000       156.000000               0.009000
# 50%    1.433800e+04          0.061000       239.000000               0.020000
# 75%    4.185200e+04          0.079000       344.750000               0.053000
# max    2.727728e+06          0.225000      2600.000000               0.141000
#
#        Internet Usage  Lending Interest  Life Expectancy Female  \
# count     2531.000000       1880.000000             2568.000000
# mean         0.239747          0.148103               71.159268
# std          0.260132          0.171829               10.708262
# min          0.000000          0.005000               39.000000
# 25%          0.000000          0.080000               64.000000
# 50%          0.100000          0.120000               75.000000
# 75%          0.400000          0.173000               79.000000
# max          1.000000          4.965000               87.000000
#
#        Life Expectancy Male  Mobile Phone Usage  Number of Records  \
# count           2568.000000         2537.000000             2704.0
# mean              66.461838            0.578124                1.0
# std                9.390217            0.474647                0.0
# min               37.000000            0.000000                1.0
# 25%               61.000000            0.100000                1.0
# 50%               69.000000            0.500000                1.0
# 75%               73.250000            0.900000                1.0
# max               88.000000            2.900000                1.0
#
#        Population 0-14  Population 15-64  Population 65+  Population Total  \
# count      2484.000000       2484.000000     2484.000000      2.704000e+03
# mean          0.303051          0.623481        0.073465      3.145729e+07
# std           0.106577          0.069660        0.049541      1.242894e+08
# min           0.118000          0.474000        0.003000      1.887600e+04
# 25%           0.204750          0.559000        0.033000      8.783360e+05
# 50%           0.299500          0.642500        0.052000      5.800324e+06
# 75%           0.402000          0.676000        0.112000      2.014089e+07
# max           0.500000          0.858000        0.244000      1.350695e+09
#
#        Population Urban
# count       2678.000000
# mean           0.562953
# std            0.245897
# min            0.082000
# 25%            0.356000
# 50%            0.560000
# 75%            0.765000
# max            1.000000

# %% [markdown]
# #### EDA

# %% [markdown]
# #### Checking for duplicates

# %%
data[data.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Birth Rate, Business Tax Rate, CO2 Emissions, Country, Days to Start Business, Ease of Business, Energy Usage, GDP, Health Exp % GDP, Health Exp/Capita, Hours to do Tax, Infant Mortality Rate, Internet Usage, Lending Interest, Life Expectancy Female, Life Expectancy Male, Mobile Phone Usage, Number of Records, Population 0-14, Population 15-64, Population 65+, Population Total, Population Urban, Tourism Inbound, Tourism Outbound]
# Index: []
#
# [0 rows x 25 columns]

# %%
#### Removing this column because it consists all ones
data.drop(['Number of Records'],inplace=True,axis=1)

# %% [markdown]
# #### Checking null Values

# %%
data.isna().sum()
# Out:
# Birth Rate                 119
# Business Tax Rate         1281
# CO2 Emissions              579
# Country                      0
# Days to Start Business     986
# Ease of Business          2519
# Energy Usage               919
# GDP                        210
# Health Exp % GDP           309
# Health Exp/Capita          309
# Hours to do Tax           1288
# Infant Mortality Rate      260
# Internet Usage             173
# Lending Interest           824
# Life Expectancy Female     136
# Life Expectancy Male       136
# Mobile Phone Usage         167
# Population 0-14            220
# Population 15-64           220
# Population 65+             220
# Population Total             0
# Population Urban            26
# Tourism Inbound            368
# Tourism Outbound           471
# dtype: int64

# %% [markdown]
# #### Filling Null Values

# %%
birth_rate_mean=data['Birth Rate'].mean()

# %%
## this line is to remove '%'
data['Business Tax Rate'] = data['Business Tax Rate'].str.rstrip('%')

# %%
## This line coverts the data into float so it will handle null values automatically
data['Business Tax Rate'] = pd.to_numeric(data['Business Tax Rate'], errors='coerce')

# %%
## Here i am using median instead of mean because Because tax rates can have outliers median is more robust 
business_tax_rate_median=data['Business Tax Rate'].median()

# %%
co2_emissions_median=data['CO2 Emissions'].median()

# %%
#### Removing this column because it has many null values
data.drop(['Ease of Business'],axis=1,inplace=True)

# %%
data.columns
# Out:
# Index(['Birth Rate', 'Business Tax Rate', 'CO2 Emissions', 'Country',
#        'Days to Start Business', 'Energy Usage', 'GDP', 'Health Exp % GDP',
#        'Health Exp/Capita', 'Hours to do Tax', 'Infant Mortality Rate',
#        'Internet Usage', 'Lending Interest', 'Life Expectancy Female',
#        'Life Expectancy Male', 'Mobile Phone Usage', 'Population 0-14',
#        'Population 15-64', 'Population 65+', 'Population Total',
#        'Population Urban', 'Tourism Inbound', 'Tourism Outbound'],
#       dtype='object')

# %%
Energy_Usage_median=data['Energy Usage'].median()

# %%
cols_to_numeric = [
    'Health Exp % GDP', 'Hours to do Tax',
    'Infant Mortality Rate', 'Internet Usage', 'Lending Interest',
    'Life Expectancy Female', 'Life Expectancy Male', 'Mobile Phone Usage',
    'Population 0-14', 'Population 15-64', 'Population 65+',
    'Population Urban', 'Energy Usage'
]

for col in cols_to_numeric:
    data[col] = pd.to_numeric(data[col], errors='coerce')

# %%
data['Health Exp % GDP'].median()
data['Hours to do Tax'].median()
data['Infant Mortality Rate'].median()
data['Internet Usage'].median()
data['Lending Interest'].mean()  # mean is fine here
data['Life Expectancy Female'].median()
data['Life Expectancy Male'].median()
data['Mobile Phone Usage'].median()
data['Population 0-14'].median()
data['Population 15-64'].median()
data['Population 65+'].median()
data['Population Urban'].median()
data['Energy Usage'].median()
# Out:
# 14338.0

# %%
currency_columns = ['GDP', 'Health Exp/Capita', 'Tourism Inbound', 'Tourism Outbound']

# Clean dollar signs and commas, then convert to numeric
for col in currency_columns:
    data[col] = data[col].astype(str).str.replace('$', '', regex=False).str.replace(',', '', regex=False).str.strip()
    data[col] = pd.to_numeric(data[col], errors='coerce')

# %%
# Step 1: Remove % symbol and strip any spaces
data['Health Exp % GDP'] = data['Health Exp % GDP'].astype(str).str.replace('%', '', regex=False).str.strip()

# Step 2: Convert to numeric
data['Health Exp % GDP'] = pd.to_numeric(data['Health Exp % GDP'], errors='coerce')

# %%
# List of columns to clean and convert
percent_columns = ['Health Exp % GDP', 'Business Tax Rate', 'Population Urban']

for col in percent_columns:
    data[col] = data[col].astype(str).str.replace('%', '', regex=False).str.strip()
    data[col] = pd.to_numeric(data[col], errors='coerce')

# %%
data.fillna(data.median(numeric_only=True), inplace=True)

# %%
# Columns with $ and commas
currency_columns = ['GDP', 'Health Exp/Capita', 'Tourism Inbound', 'Tourism Outbound']

for col in currency_columns:
    data[col] = data[col].astype(str)  # Ensure string
    data[col] = data[col].str.replace('$', '', regex=False)
    data[col] = data[col].str.replace(',', '', regex=False)
    data[col] = pd.to_numeric(data[col], errors='coerce')

# %%
data.fillna({
    'Birth Rate': data['Birth Rate'].median(),
    'Business Tax Rate': data['Business Tax Rate'].median(),
    'CO2 Emissions': data['CO2 Emissions'].median(),
    'Days to Start Business': data['Days to Start Business'].median(),
    'Energy Usage': data['Energy Usage'].median(),
    'GDP': data['GDP'].median(),
    'Health Exp % GDP': data['Health Exp % GDP'].median(),
    'Health Exp/Capita': data['Health Exp/Capita'].median(),
    'Hours to do Tax': data['Hours to do Tax'].median(),
    'Infant Mortality Rate': data['Infant Mortality Rate'].median(),
    'Internet Usage': data['Internet Usage'].median(),
    'Lending Interest': data['Lending Interest'].mean(),  # mean used here
    'Life Expectancy Female': data['Life Expectancy Female'].median(),
    'Life Expectancy Male': data['Life Expectancy Male'].median(),
    'Mobile Phone Usage': data['Mobile Phone Usage'].median(),
    'Population 0-14': data['Population 0-14'].median(),
    'Population 15-64': data['Population 15-64'].median(),
    'Population 65+': data['Population 65+'].median(),
    'Population Urban': data['Population Urban'].median(),
    'Tourism Inbound': data['Tourism Inbound'].median(),
    'Tourism Outbound': data['Tourism Outbound'].median()
}, inplace=True)

# %%
data.isna().sum()
# Out:
# Birth Rate                0
# Business Tax Rate         0
# CO2 Emissions             0
# Country                   0
# Days to Start Business    0
# Energy Usage              0
# GDP                       0
# Health Exp % GDP          0
# Health Exp/Capita         0
# Hours to do Tax           0
# Infant Mortality Rate     0
# Internet Usage            0
# Lending Interest          0
# Life Expectancy Female    0
# Life Expectancy Male      0
# Mobile Phone Usage        0
# Population 0-14           0
# Population 15-64          0
# Population 65+            0
# Population Total          0
# Population Urban          0
# Tourism Inbound           0
# Tourism Outbound          0
# dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2704 entries, 0 to 2703
# Data columns (total 23 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Birth Rate              2704 non-null   float64
#  1   Business Tax Rate       2704 non-null   float64
#  2   CO2 Emissions           2704 non-null   float64
#  3   Country                 2704 non-null   object
#  4   Days to Start Business  2704 non-null   float64
#  5   Energy Usage            2704 non-null   float64
#  6   GDP                     2704 non-null   float64
#  7   Health Exp % GDP        2704 non-null   float64
#  8   Health Exp/Capita       2704 non-null   float64
#  9   Hours to do Tax         2704 non-null   float64
#  10  Infant Mortality Rate   2704 non-null   float64
#  11  Internet Usage          2704 non-null   float64
#  12  Lending Interest        2704 non-null   float64
#  13  Life Expectancy Female  2704 non-null   float64
#  14  Life Expectancy Male    2704 non-null   float64
#  15  Mobile Phone Usage      2704 non-null   float64
#  16  Population 0-14         2704 non-null   float64
#  17  Population 15-64        2704 non-null   float64
#  18  Population 65+          2704 non-null   float64
#  19  Population Total        2704 non-null   int64
#  20  Population Urban        2704 non-null   float64
#  21  Tourism Inbound         2704 non-null   float64
#  22  Tourism Outbound        2704 non-null   float64
# dtypes: float64(21), int64(1), object(1)
# memory usage: 486.0+ KB

# %%
data.head()
# Out:
#    Birth Rate  Business Tax Rate  CO2 Emissions       Country  \
# 0       0.020               41.0        87931.0       Algeria
# 1       0.050               41.0         9542.0        Angola
# 2       0.043               41.0         1617.0         Benin
# 3       0.027               41.0         4276.0      Botswana
# 4       0.046               41.0         1041.0  Burkina Faso
#
#    Days to Start Business  Energy Usage           GDP  Health Exp % GDP  \
# 0                    26.0       26998.0  5.479006e+10             0.035
# 1                    26.0        7499.0  9.129595e+09             0.034
# 2                    26.0        1983.0  2.359122e+09             0.043
# 3                    26.0        1836.0  5.788312e+09             0.047
# 4                    26.0       14338.0  2.610959e+09             0.051
#
#    Health Exp/Capita  Hours to do Tax  ...  Life Expectancy Female  \
# 0               60.0            239.0  ...                    71.0
# 1               22.0            239.0  ...                    47.0
# 2               15.0            239.0  ...                    57.0
# 3              152.0            239.0  ...                    52.0
# 4               12.0            239.0  ...                    52.0
#
#    Life Expectancy Male  Mobile Phone Usage  Population 0-14  \
# 0                  67.0                 0.0            0.342
# 1                  44.0                 0.0            0.476
# 2                  53.0                 0.0            0.454
# 3                  49.0                 0.1            0.383
# 4                  49.0                 0.0            0.468
#
#    Population 15-64  Population 65+  Population Total  Population Urban  \
# 0             0.619           0.039          31719449             0.599
# 1             0.499           0.025          13924930             0.324
# 2             0.517           0.029           6949366             0.383
# 3             0.587           0.029           1755375             0.532
# 4             0.505           0.028          11607944             0.178
#
#    Tourism Inbound  Tourism Outbound
# 0      102000000.0       193000000.0
# 1       34000000.0       146000000.0
# 2       77000000.0        50000000.0
# 3      227000000.0       209000000.0
# 4       23000000.0        30000000.0
#
# [5 rows x 23 columns]

# %% [markdown]
# #### Visualization

# %%
top_countries = data['Country'].value_counts().nlargest(10)

# Plot
plt.figure(figsize=(10, 6))
sns.barplot(x=top_countries.values, y=top_countries.index, palette='viridis')
plt.title('Top 10 Countries by Count')
plt.xlabel('Count')
plt.ylabel('Country')
plt.tight_layout()
plt.show()

# %%
num_columns=data.select_dtypes(['number'])
num_columns
# Out:
#       Birth Rate  Business Tax Rate  CO2 Emissions  Days to Start Business  \
# 0          0.020               41.0        87931.0                    26.0
# 1          0.050               41.0         9542.0                    26.0
# 2          0.043               41.0         1617.0                    26.0
# 3          0.027               41.0         4276.0                    26.0
# 4          0.046               41.0         1041.0                    26.0
# ...          ...                ...            ...                     ...
# 2699       0.020               41.0         8529.0                    26.0
# 2700       0.013               46.4         8529.0                     5.0
# 2701       0.015               41.9         8529.0                     7.0
# 2702       0.020               61.9         8529.0                   144.0
# 2703       0.011               41.0         8529.0                    26.0
#
#       Energy Usage           GDP  Health Exp % GDP  Health Exp/Capita  \
# 0          26998.0  5.479006e+10             0.035               60.0
# 1           7499.0  9.129595e+09             0.034               22.0
# 2           1983.0  2.359122e+09             0.043               15.0
# 3           1836.0  5.788312e+09             0.047              152.0
# 4          14338.0  2.610959e+09             0.051               12.0
# ...            ...           ...               ...                ...
# 2699       14338.0  1.507975e+10             0.061              193.0
# 2700     2132446.0  1.624460e+13             0.179             8895.0
# 2701       14338.0  5.000435e+10             0.089             1308.0
# 2702       14338.0  3.812862e+11             0.046              593.0
# 2703       14338.0  1.507975e+10             0.061              193.0
#
#       Hours to do Tax  Infant Mortality Rate  ...  Life Expectancy Female  \
# 0               239.0                  0.034  ...                    71.0
# 1               239.0                  0.128  ...                    47.0
# 2               239.0                  0.090  ...                    57.0
# 3               239.0                  0.054  ...                    52.0
# 4               239.0                  0.096  ...                    52.0
# ...               ...                    ...  ...                     ...
# 2699            239.0                  0.020  ...                    75.0
# 2700            175.0                  0.006  ...                    81.0
# 2701            310.0                  0.010  ...                    80.0
# 2702            792.0                  0.013  ...                    78.0
# 2703            239.0                  0.020  ...                    83.0
#
#       Life Expectancy Male  Mobile Phone Usage  Population 0-14  \
# 0                     67.0                 0.0           0.3420
# 1                     44.0                 0.0           0.4760
# 2                     53.0                 0.0           0.4540
# 3                     49.0                 0.1           0.3830
# 4                     49.0                 0.0           0.4680
# ...                    ...                 ...              ...
# 2699                  69.0                 0.5           0.2995
# 2700                  76.0                 1.0           0.1960
# 2701                  74.0                 1.5           0.2200
# 2702                  72.0                 1.0           0.2880
# 2703                  76.0                 0.5           0.2060
#
#       Population 15-64  Population 65+  Population Total  Population Urban  \
# 0               0.6190           0.039          31719449             0.599
# 1               0.4990           0.025          13924930             0.324
# 2               0.5170           0.029           6949366             0.383
# 3               0.5870           0.029           1755375             0.532
# 4               0.5050           0.028          11607944             0.178
# ...                ...             ...               ...               ...
# 2699            0.6425           0.052             32427             0.911
# 2700            0.6670           0.136         313873685             0.811
# 2701            0.6390           0.140           3395253             0.948
# 2702            0.6520           0.060          29954782             0.889
# 2703            0.6410           0.152            105275             0.949
#
#       Tourism Inbound  Tourism Outbound
# 0        1.020000e+08      1.930000e+08
# 1        3.400000e+07      1.460000e+08
# 2        7.700000e+07      5.000000e+07
# 3        2.270000e+08      2.090000e+08
# 4        2.300000e+07      3.000000e+07
# ...               ...               ...
# 2699     6.885000e+08      4.560000e+08
# 2700     2.000920e+11      1.265730e+11
# 2701     2.222000e+09      1.028000e+09
# 2702     9.040000e+08      3.202000e+09
# 2703     6.885000e+08      4.560000e+08
#
# [2704 rows x 22 columns]

# %%
plt.figure(figsize=(6,3))
for cols in num_columns:
    plt.hist(data[cols],bins=5,edgecolor='white')
    plt.xlabel(cols)
    plt.ylabel('Frequency')
    plt.title(f'Histogram for {cols}')
    plt.show()

# %% [markdown]
# #### Scaling the data

# %%
## Here I am Applying MinMax normalization for this selected high-range numerical features to bring them to a common scale for effective clustering
columns_to_normalize = [
    'Business_Tax_Rate',
    'CO2_Emissions',
    'Days_to_Start_Business',
    'Energy_Usage',
    'GDP',
    'Health_Exp_per_Capita',
    'Hours_to_do_Tax',
    'Lending_Interest',
    'Life_Expectancy_Female',
    'Life_Expectancy_Male',
    'Mobile_Phone_Usage',
    'Population_Total',
    'Tourism_Inbound',
    'Tourism_Outbound'
]

# %%
data.columns = data.columns.str.strip().str.lower().str.replace(' ', '_').str.replace('+', 'plus').str.replace('-', '_').str.replace('%', 'percentage')

# %%
columns_to_normalize = [
    'birth_rate', 'business_tax_rate', 'co2_emissions', 'days_to_start_business',
    'energy_usage', 'gdp', 'health_exp_percentage_gdp', 'health_exp/capita',
    'hours_to_do_tax', 'infant_mortality_rate', 'internet_usage', 'lending_interest',
    'life_expectancy_female', 'life_expectancy_male', 'mobile_phone_usage',
    'population_0_14', 'population_15_64', 'population_65plus',
    'population_urban', 'tourism_inbound', 'tourism_outbound'
]

# %% [markdown]
# #### RobusterScaler is designed specifially to handle outliers by scaling based on median and IQR

# %%
from sklearn.preprocessing import RobustScaler

# %%
from sklearn.preprocessing import RobustScaler

columns_to_normalize = ['gdp', 'co2_emissions', 'health_exp/capita', 
                        'business_tax_rate', 'energy_usage', 'birth_rate']

for cols in columns_to_normalize:
    scaler = RobustScaler()
    data[cols] = scaler.fit_transform(data[[cols]])

# %%
data.describe()
# Out:
#         birth_rate  business_tax_rate  co2_emissions  days_to_start_business  \
# count  2704.000000        2704.000000    2704.000000             2704.000000
# mean      0.152671           2.206653       2.607131               34.894601
# std       0.652942          15.773639      13.607987               46.177780
# min      -0.764706         -17.263158      -0.211333                1.000000
# 25%      -0.411765          -0.315789      -0.156032               20.000000
# 50%       0.000000           0.000000       0.000000               26.000000
# 75%       0.588235           0.684211       0.843968               34.250000
# max       1.941176         156.894737     205.291085              694.000000
#
#        energy_usage          gdp  health_exp_percentage_gdp  \
# count   2704.000000  2704.000000                2704.000000
# mean       2.657426     2.640298                   0.063807
# std       13.648632    12.509965                   0.024795
# min       -0.917135    -0.172795                   0.008000
# 25%       -0.415127    -0.126185                   0.048000
# 50%        0.000000     0.000000                   0.061000
# 75%        0.584873     0.873815                   0.076000
# max      173.659739   186.751193                   0.225000
#
#        health_exp/capita  hours_to_do_tax  infant_mortality_rate  ...  \
# count        2704.000000      2704.000000            2704.000000  ...
# mean            1.092493       272.026997               0.031581  ...
# std             2.838563       200.233912               0.028739  ...
# min            -0.387228        12.000000               0.002000  ...
# 25%            -0.273695       229.500000               0.010000  ...
# 50%             0.000000       239.000000               0.020000  ...
# 75%             0.726305       256.000000               0.049000  ...
# max            19.695895      2600.000000               0.141000  ...
#
#        life_expectancy_female  life_expectancy_male  mobile_phone_usage  \
# count             2704.000000           2704.000000         2704.000000
# mean                71.352441             66.589497            0.573299
# std                 10.469114              9.167741            0.460136
# min                 39.000000             37.000000            0.000000
# 25%                 65.000000             61.000000            0.200000
# 50%                 75.000000             69.000000            0.500000
# 75%                 79.000000             73.000000            0.900000
# max                 87.000000             88.000000            2.900000
#
#        population_0_14  population_15_64  population_65plus  population_total  \
# count      2704.000000       2704.000000        2704.000000      2.704000e+03
# mean          0.302762          0.625029           0.071718      3.145729e+07
# std           0.102152          0.066967           0.047844      1.242894e+08
# min           0.118000          0.474000           0.003000      1.887600e+04
# 25%           0.210000          0.565000           0.034000      8.783360e+05
# 50%           0.299500          0.642500           0.052000      5.800324e+06
# 75%           0.395000          0.673000           0.105000      2.014089e+07
# max           0.500000          0.858000           0.244000      1.350695e+09
#
#        population_urban  tourism_inbound  tourism_outbound
# count       2704.000000     2.704000e+03      2.704000e+03
# mean           0.562924     4.360806e+09      3.985061e+09
# std            0.244712     1.295591e+10      1.216499e+10
# min            0.082000     7.000000e+05      2.000000e+05
# 25%            0.357750     1.860000e+08      1.470000e+08
# 50%            0.560000     6.885000e+08      4.560000e+08
# 75%            0.763000     2.648000e+09      1.711500e+09
# max            1.000000     2.000920e+11      1.265730e+11
#
# [8 rows x 22 columns]

# %%
parameters = ['gdp', 'co2_emissions', 'health_exp/capita', 
              'business_tax_rate', 'energy_usage', 'birth_rate']

for param in parameters:
    top_countries = data[['country', param]].dropna().sort_values(by=param, ascending=False).drop_duplicates(subset='country').head(10)
    plt.figure(figsize=(10, 6))
    sns.barplot(x=param, y='country', data=top_countries, palette='crest')
    plt.title(f'Top 10 Countries by {param.replace("_", " ").title()}')
    plt.xlabel(param.replace("_", " ").title())
    plt.ylabel('Country')
    plt.tight_layout()
    plt.show()

# %%
#### Here i am copying original data because here i dont want country column it is not effective in clustering

# %%
data1=data.copy()

# %%
data1.drop('country', axis=1, inplace=True)

# %%
correlation=data1.corr()
correlation
# Out:
#                            birth_rate  business_tax_rate  co2_emissions  \
# birth_rate                   1.000000           0.210435      -0.148665
# business_tax_rate            0.210435           1.000000       0.025192
# co2_emissions               -0.148665           0.025192       1.000000
# days_to_start_business       0.142392           0.022330      -0.027550
# energy_usage                -0.159230           0.027167       0.908944
# gdp                         -0.184839           0.016925       0.693480
# health_exp_percentage_gdp   -0.203536           0.044159       0.144582
# health_exp/capita           -0.411804          -0.073806       0.207046
# hours_to_do_tax              0.055880           0.157252       0.066940
# infant_mortality_rate        0.866444           0.222757      -0.107813
# internet_usage              -0.624617          -0.125095       0.094055
# lending_interest             0.219265           0.092181      -0.069461
# life_expectancy_female      -0.864448          -0.202413       0.106685
# life_expectancy_male        -0.821947          -0.220166       0.112328
# mobile_phone_usage          -0.536971          -0.106278       0.016765
# population_0_14              0.941822           0.158522      -0.169931
# population_15_64            -0.906371          -0.188364       0.158759
# population_65plus           -0.737706          -0.073951       0.142830
# population_total            -0.054973           0.053004       0.655298
# population_urban            -0.592360          -0.093333       0.073803
# tourism_inbound             -0.270296           0.000344       0.591023
# tourism_outbound            -0.275113          -0.004125       0.561877
#
#                            days_to_start_business  energy_usage       gdp  \
# birth_rate                               0.142392     -0.159230 -0.184839
# business_tax_rate                        0.022330      0.027167  0.016925
# co2_emissions                           -0.027550      0.908944  0.693480
# days_to_start_business                   1.000000     -0.037432 -0.058190
# energy_usage                            -0.037432      1.000000  0.852598
# gdp                                     -0.058190      0.852598  1.000000
# health_exp_percentage_gdp               -0.101871      0.204383  0.330315
# health_exp/capita                       -0.142882      0.283808  0.451191
# hours_to_do_tax                          0.151162      0.069807  0.040062
# infant_mortality_rate                    0.149225     -0.118395 -0.167284
# internet_usage                          -0.177596      0.144599  0.269814
# lending_interest                         0.122403     -0.075341 -0.088957
# life_expectancy_female                  -0.162751      0.121721  0.183728
# life_expectancy_male                    -0.172542      0.127748  0.195792
# mobile_phone_usage                      -0.111373      0.044601  0.128016
# population_0_14                          0.163997     -0.187804 -0.228162
# population_15_64                        -0.136081      0.162603  0.150629
# population_65plus                       -0.157461      0.175438  0.278436
# population_total                         0.011373      0.653808  0.381322
# population_urban                        -0.083134      0.093780  0.164949
# tourism_inbound                         -0.095646      0.738068  0.880682
# tourism_outbound                        -0.091924      0.696566  0.858337
#
#                            health_exp_percentage_gdp  health_exp/capita  \
# birth_rate                                 -0.203536          -0.411804
# business_tax_rate                           0.044159          -0.073806
# co2_emissions                               0.144582           0.207046
# days_to_start_business                     -0.101871          -0.142882
# energy_usage                                0.204383           0.283808
# gdp                                         0.330315           0.451191
# health_exp_percentage_gdp                   1.000000           0.445972
# health_exp/capita                           0.445972           1.000000
# hours_to_do_tax                            -0.040249          -0.153628
# infant_mortality_rate                      -0.157454          -0.426319
# internet_usage                              0.308803           0.704815
# lending_interest                           -0.018288          -0.161464
# life_expectancy_female                      0.183905           0.440373
# life_expectancy_male                        0.193580           0.477241
# mobile_phone_usage                          0.163672           0.418276
# population_0_14                            -0.262464          -0.478777
# population_15_64                            0.081764           0.320361
# population_65plus                           0.445454           0.573116
# population_total                           -0.050497           0.005577
# population_urban                            0.178169           0.438859
# tourism_inbound                             0.368690           0.524197
# tourism_outbound                            0.353248           0.553759
#
#                            hours_to_do_tax  infant_mortality_rate  ...  \
# birth_rate                        0.055880               0.866444  ...
# business_tax_rate                 0.157252               0.222757  ...
# co2_emissions                     0.066940              -0.107813  ...
# days_to_start_business            0.151162               0.149225  ...
# energy_usage                      0.069807              -0.118395  ...
# gdp                               0.040062              -0.167284  ...
# health_exp_percentage_gdp        -0.040249              -0.157454  ...
# health_exp/capita                -0.153628              -0.426319  ...
# hours_to_do_tax                   1.000000               0.082720  ...
# infant_mortality_rate             0.082720               1.000000  ...
# internet_usage                   -0.115383              -0.610248  ...
# lending_interest                  0.102178               0.237365  ...
# life_expectancy_female           -0.076614              -0.922481  ...
# life_expectancy_male             -0.108671              -0.900726  ...
# mobile_phone_usage               -0.005034              -0.563304  ...
# population_0_14                   0.048673               0.808403  ...
# population_15_64                 -0.059124              -0.790545  ...
# population_65plus                -0.019068              -0.614331  ...
# population_total                  0.123811               0.017421  ...
# population_urban                 -0.003348              -0.594938  ...
# tourism_inbound                  -0.035452              -0.244072  ...
# tourism_outbound                 -0.016411              -0.247918  ...
#
#                            life_expectancy_female  life_expectancy_male  \
# birth_rate                              -0.864448             -0.821947
# business_tax_rate                       -0.202413             -0.220166
# co2_emissions                            0.106685              0.112328
# days_to_start_business                  -0.162751             -0.172542
# energy_usage                             0.121721              0.127748
# gdp                                      0.183728              0.195792
# health_exp_percentage_gdp                0.183905              0.193580
# health_exp/capita                        0.440373              0.477241
# hours_to_do_tax                         -0.076614             -0.108671
# infant_mortality_rate                   -0.922481             -0.900726
# internet_usage                           0.638764              0.658345
# lending_interest                        -0.278083             -0.287180
# life_expectancy_female                   1.000000              0.976893
# life_expectancy_male                     0.976893              1.000000
# mobile_phone_usage                       0.547038              0.547375
# population_0_14                         -0.810456             -0.766829
# population_15_64                         0.777218              0.746274
# population_65plus                        0.637136              0.587557
# population_total                         0.001669              0.019167
# population_urban                         0.619503              0.617830
# tourism_inbound                          0.273970              0.290037
# tourism_outbound                         0.271628              0.291095
#
#                            mobile_phone_usage  population_0_14  \
# birth_rate                          -0.536971         0.941822
# business_tax_rate                   -0.106278         0.158522
# co2_emissions                        0.016765        -0.169931
# days_to_start_business              -0.111373         0.163997
# energy_usage                         0.044601        -0.187804
# gdp                                  0.128016        -0.228162
# health_exp_percentage_gdp            0.163672        -0.262464
# health_exp/capita                    0.418276        -0.478777
# hours_to_do_tax                     -0.005034         0.048673
# infant_mortality_rate               -0.563304         0.808403
# internet_usage                       0.742168        -0.675302
# lending_interest                    -0.226158         0.224725
# life_expectancy_female               0.547038        -0.810456
# life_expectancy_male                 0.547375        -0.766829
# mobile_phone_usage                   1.000000        -0.605139
# population_0_14                     -0.605139         1.000000
# population_15_64                     0.576607        -0.924451
# population_65plus                    0.482341        -0.841037
# population_total                    -0.056869        -0.059294
# population_urban                     0.461155        -0.603919
# tourism_inbound                      0.245065        -0.333219
# tourism_outbound                     0.238461        -0.343386
#
#                            population_15_64  population_65plus  \
# birth_rate                        -0.906371          -0.737706
# business_tax_rate                 -0.188364          -0.073951
# co2_emissions                      0.158759           0.142830
# days_to_start_business            -0.136081          -0.157461
# energy_usage                       0.162603           0.175438
# gdp                                0.150629           0.278436
# health_exp_percentage_gdp          0.081764           0.445454
# health_exp/capita                  0.320361           0.573116
# hours_to_do_tax                   -0.059124          -0.019068
# infant_mortality_rate             -0.790545          -0.614331
# internet_usage                     0.586613           0.615884
# lending_interest                  -0.224003          -0.164316
# life_expectancy_female             0.777218           0.637136
# life_expectancy_male               0.746274           0.587557
# mobile_phone_usage                 0.576607           0.482341
# population_0_14                   -0.924451          -0.841037
# population_15_64                   1.000000           0.571661
# population_65plus                  0.571661           1.000000
# population_total                   0.084455           0.010982
# population_urban                   0.590908           0.455545
# tourism_inbound                    0.234369           0.386382
# tourism_outbound                   0.226189           0.419460
#
#                            population_total  population_urban  \
# birth_rate                        -0.054973         -0.592360
# business_tax_rate                  0.053004         -0.093333
# co2_emissions                      0.655298          0.073803
# days_to_start_business             0.011373         -0.083134
# energy_usage                       0.653808          0.093780
# gdp                                0.381322          0.164949
# health_exp_percentage_gdp         -0.050497          0.178169
# health_exp/capita                  0.005577          0.438859
# hours_to_do_tax                    0.123811         -0.003348
# infant_mortality_rate              0.017421         -0.594938
# internet_usage                    -0.037488          0.531437
# lending_interest                  -0.030616         -0.147258
# life_expectancy_female             0.001669          0.619503
# life_expectancy_male               0.019167          0.617830
# mobile_phone_usage                -0.056869          0.461155
# population_0_14                   -0.059294         -0.603919
# population_15_64                   0.084455          0.590908
# population_65plus                  0.010982          0.455545
# population_total                   1.000000         -0.069252
# population_urban                  -0.069252          1.000000
# tourism_inbound                    0.303711          0.229505
# tourism_outbound                   0.326481          0.252252
#
#                            tourism_inbound  tourism_outbound
# birth_rate                       -0.270296         -0.275113
# business_tax_rate                 0.000344         -0.004125
# co2_emissions                     0.591023          0.561877
# days_to_start_business           -0.095646         -0.091924
# energy_usage                      0.738068          0.696566
# gdp                               0.880682          0.858337
# health_exp_percentage_gdp         0.368690          0.353248
# health_exp/capita                 0.524197          0.553759
# hours_to_do_tax                  -0.035452         -0.016411
# infant_mortality_rate            -0.244072         -0.247918
# internet_usage                    0.361647          0.406839
# lending_interest                 -0.123352         -0.122442
# life_expectancy_female            0.273970          0.271628
# life_expectancy_male              0.290037          0.291095
# mobile_phone_usage                0.245065          0.238461
# population_0_14                  -0.333219         -0.343386
# population_15_64                  0.234369          0.226189
# population_65plus                 0.386382          0.419460
# population_total                  0.303711          0.326481
# population_urban                  0.229505          0.252252
# tourism_inbound                   1.000000          0.859486
# tourism_outbound                  0.859486          1.000000
#
# [22 rows x 22 columns]

# %%
plt.figure(figsize=(14,8))
sns.heatmap(correlation,annot=True)
# Out:
# <Axes: >

# %%
columns_to_drop = [
    'infant_mortality_rate',
    'life_expectancy_male',
    'population_0_14',
    'co2_emissions',
    'tourism_inbound',
    'tourism_outbound'
]

data1.drop(columns=columns_to_drop, inplace=True)

# %%
data1.head()
# Out:
#    birth_rate  business_tax_rate  days_to_start_business  energy_usage  \
# 0    0.000000                0.0                    26.0      0.810253
# 1    1.764706                0.0                    26.0     -0.437703
# 2    1.352941                0.0                    26.0     -0.790733
# 3    0.411765                0.0                    26.0     -0.800141
# 4    1.529412                0.0                    26.0      0.000000
#
#         gdp  health_exp_percentage_gdp  health_exp/capita  hours_to_do_tax  \
# 0  0.456942                      0.035          -0.269640            239.0
# 1 -0.068468                      0.034          -0.346680            239.0
# 2 -0.146375                      0.043          -0.360872            239.0
# 3 -0.106916                      0.047          -0.083122            239.0
# 4 -0.143477                      0.051          -0.366954            239.0
#
#    internet_usage  lending_interest  life_expectancy_female  \
# 0             0.0             0.100                    71.0
# 1             0.0             1.032                    47.0
# 2             0.0             0.120                    57.0
# 3             0.0             0.155                    52.0
# 4             0.0             0.120                    52.0
#
#    mobile_phone_usage  population_15_64  population_65plus  population_total  \
# 0                 0.0             0.619              0.039          31719449
# 1                 0.0             0.499              0.025          13924930
# 2                 0.0             0.517              0.029           6949366
# 3                 0.1             0.587              0.029           1755375
# 4                 0.0             0.505              0.028          11607944
#
#    population_urban
# 0             0.599
# 1             0.324
# 2             0.383
# 3             0.532
# 4             0.178

# %% [markdown]
# #### PCA

# %%
from sklearn.decomposition import PCA

# %% [markdown]
# #### Getting the principle components

# %%
pca=PCA()
pcomps=pca.fit_transform(data1)
pcomps
# Out:
# array([[ 2.62155105e+05, -3.34026850e+01, -7.55516002e+00, ...,
#         -2.52323431e-02, -1.51131457e-02, -2.07439211e-01],
#        [-1.75323639e+07, -2.97513385e+01, -6.71900406e+00, ...,
#         -6.90560299e-04, -3.41589639e-02,  3.31769497e-01],
#        [-2.45079279e+07, -2.84014014e+01, -7.11999582e+00, ...,
#          8.97454645e-03, -1.84679429e-02,  4.17930169e-01],
#        ...,
#        [-2.80620409e+07,  4.24524491e+01, -2.96479051e+01, ...,
#          6.54408851e-02,  1.57360108e-03,  5.44284086e-02],
#        [-1.50251189e+06,  5.23990632e+02,  8.93474454e+01, ...,
#         -2.62277212e-02, -6.35061099e-03,  1.97241645e-01],
#        [-3.13520189e+07, -2.71465250e+01, -8.14349642e+00, ...,
#          7.49420254e-02, -2.65781645e-02, -9.11344429e-02]])

# %%
ratio=pca.explained_variance_ratio_
ratio
# Out:
# array([1.00000000e+00, 2.55938369e-12, 1.34956238e-13, 1.63146730e-14,
#        1.47543364e-14, 6.13849149e-15, 1.07163523e-15, 3.10448589e-16,
#        9.63093417e-18, 2.17399290e-18, 1.20482086e-18, 9.03128670e-19,
#        1.20840131e-19, 6.78874580e-20, 2.43885938e-20, 0.00000000e+00])

# %%
vars = np.round(np.cumsum(ratio)*100,1)
vars
# Out:
# array([100., 100., 100., 100., 100., 100., 100., 100., 100., 100., 100.,
#        100., 100., 100., 100., 100.])

# %%
plt.figure(figsize=(6,3))
plt.plot(range(1,17),vars, linestyle='dotted',
         marker='H',markerfacecolor='orange'
        )
plt.title('The Explained Variances')
plt.xlabel('Principal Components')
plt.ylabel('Information Included')
plt.show()

# %%
plt.figure(figsize=(6,3))
plt.bar(x= range(1,17),
        height=ratio,
        color='purple'
       )
plt.title('The Information Contained in Principal Components')
plt.xlabel('Principal Components')
plt.ylabel('Information Contained')
plt.show()

# %%
from mpl_toolkits.mplot3d import Axes3D

fig = plt.figure(figsize=(10, 6))
ax = fig.add_subplot(111, projection='3d')
ax.scatter(pcomps[:, 0], pcomps[:, 1], pcomps[:, 2], alpha=0.7)
ax.set_xlabel('PC1')
ax.set_ylabel('PC2')
ax.set_zlabel('PC3')
ax.set_title('3D PCA Scatter Plot')
plt.show()

# %%
data2 = pd.DataFrame({'PC1':pcomps[:,0], 'PC2':pcomps[:,1],'PC3':pcomps[:,2],'PC4':pcomps[:,3]})
data2
# Out:
#                PC1         PC2        PC3        PC4
# 0     2.621551e+05  -33.402685  -7.555160  -0.401689
# 1    -1.753236e+07  -29.751339  -6.719004   5.904484
# 2    -2.450793e+07  -28.401401  -7.119996   3.242748
# 3    -2.970192e+07  -27.345357  -6.965251   4.404007
# 4    -1.984935e+07  -29.310396  -6.922198   4.479500
# ...            ...         ...        ...        ...
# 2699 -3.142487e+07  -27.098503  -7.845143  -1.826594
# 2700  2.824164e+08 -154.659253 -30.895357 -66.203593
# 2701 -2.806204e+07   42.452449 -29.647905  -3.341073
# 2702 -1.502512e+06  523.990632  89.347445  -1.698049
# 2703 -3.135202e+07  -27.146525  -8.143496  -3.918717
#
# [2704 rows x 4 columns]

# %% [markdown]
# #### Model Building

# %%
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score

# %%
sil = []
K = range(2, 10)
for k in K:
    kmeans = KMeans(n_clusters=k, random_state=42)
    labels = kmeans.fit_predict(data2)
    sil.append(silhouette_score(data2, labels))

# %%
plt.plot(K, sil, marker='o')
plt.xlabel('No. of Clusters (k)')
plt.ylabel('Silhouette Score')
plt.title('KMeans Clustering Performance')
plt.show()

# %%
kmeans = KMeans(n_clusters=3, random_state=42)
data2['Kmeans'] = kmeans.fit_predict(data2)

# %%
data1['Kmeans']=kmeans.labels_

# %%
kmeans_score = silhouette_score(data2, data2['Kmeans'])
print(f'Silhouette Score (KMeans): {kmeans_score:.4f}')
# Out:
# Silhouette Score (KMeans): 0.8640

# %%
plt.scatter(data2['PC1'], data2['PC2'], c=data2['Kmeans'], cmap='Set2')
plt.title("K-Means Clustering with k=3")
plt.xlabel("PC1")
plt.ylabel("PC2")
plt.grid(True)
plt.show()

# %%
from sklearn.manifold import TSNE

# %%
tsne = TSNE(n_components=2
           )
tcomps = tsne.fit_transform(data1)

# %%
plt.figure(figsize=(10,4))

plt.scatter(tcomps[:,0], tcomps[:,1], 
            cmap='viridis', 
            c=data1['Kmeans'],
            alpha=0.5,
            edgecolors='white'
           )
plt.show()

# %%
data1.head()
# Out:
#    birth_rate  business_tax_rate  days_to_start_business  energy_usage  \
# 0    0.000000                0.0                    26.0      0.810253
# 1    1.764706                0.0                    26.0     -0.437703
# 2    1.352941                0.0                    26.0     -0.790733
# 3    0.411765                0.0                    26.0     -0.800141
# 4    1.529412                0.0                    26.0      0.000000
#
#         gdp  health_exp_percentage_gdp  health_exp/capita  hours_to_do_tax  \
# 0  0.456942                      0.035          -0.269640            239.0
# 1 -0.068468                      0.034          -0.346680            239.0
# 2 -0.146375                      0.043          -0.360872            239.0
# 3 -0.106916                      0.047          -0.083122            239.0
# 4 -0.143477                      0.051          -0.366954            239.0
#
#    internet_usage  lending_interest  life_expectancy_female  \
# 0             0.0             0.100                    71.0
# 1             0.0             1.032                    47.0
# 2             0.0             0.120                    57.0
# 3             0.0             0.155                    52.0
# 4             0.0             0.120                    52.0
#
#    mobile_phone_usage  population_15_64  population_65plus  population_total  \
# 0                 0.0             0.619              0.039          31719449
# 1                 0.0             0.499              0.025          13924930
# 2                 0.0             0.517              0.029           6949366
# 3                 0.1             0.587              0.029           1755375
# 4                 0.0             0.505              0.028          11607944
#
#    population_urban  Kmeans
# 0             0.599       0
# 1             0.324       0
# 2             0.383       0
# 3             0.532       0
# 4             0.178       0

# %%
from sklearn.cluster import AgglomerativeClustering
from scipy.cluster.hierarchy import dendrogram, linkage

# %%
plt.figure(figsize=(12, 6))
linked = linkage(data2, method='ward')  # 'ward' minimizes variance within clusters
dendrogram(linked)
plt.title('Dendrogram')
plt.xlabel('Samples')
plt.ylabel('Euclidean Distance')
plt.show()

# %%
from sklearn.cluster import AgglomerativeClustering

hc = AgglomerativeClustering(n_clusters=3, metric='euclidean', linkage='ward')
labels = hc.fit_predict(data2)  # use scaled_data, not raw data2

# Add labels to your data
data1['heirarchical'] = labels
data2['heirarchical']=labels

# %%
score = silhouette_score(data2, labels)
print(f'Silhouette Score (Hierarchical Clustering): {score:.4f}')
# Out:
# Silhouette Score (Hierarchical Clustering): 0.8660

# %%
data2
# Out:
#                PC1         PC2        PC3        PC4  Kmeans  heirarchical
# 0     2.621551e+05  -33.402685  -7.555160  -0.401689       0             0
# 1    -1.753236e+07  -29.751339  -6.719004   5.904484       0             0
# 2    -2.450793e+07  -28.401401  -7.119996   3.242748       0             0
# 3    -2.970192e+07  -27.345357  -6.965251   4.404007       0             0
# 4    -1.984935e+07  -29.310396  -6.922198   4.479500       0             0
# ...            ...         ...        ...        ...     ...           ...
# 2699 -3.142487e+07  -27.098503  -7.845143  -1.826594       0             0
# 2700  2.824164e+08 -154.659253 -30.895357 -66.203593       2             2
# 2701 -2.806204e+07   42.452449 -29.647905  -3.341073       0             0
# 2702 -1.502512e+06  523.990632  89.347445  -1.698049       0             0
# 2703 -3.135202e+07  -27.146525  -8.143496  -3.918717       0             0
#
# [2704 rows x 6 columns]

# %%
print(data2['Kmeans'].value_counts())
print(data2['heirarchical'].value_counts())
# Out:
# Kmeans
# 0    2556
# 2     122
# 1      26
# Name: count, dtype: int64
# heirarchical
# 0    2561
# 2     117
# 1      26
# Name: count, dtype: int64

# %%
# Cluster 0
print("\nCluster 0 Means:")
print(data1[data1['Kmeans'] == 0].mean(numeric_only=True).round(2))
# Cluster 1
print("\nCluster 1 Means:")
print(data1[data1['Kmeans'] == 1].mean(numeric_only=True).round(2))
# Cluster 2
print("\nCluster 2 Means:")
print(data1[data1['Kmeans'] == 2].mean(numeric_only=True).round(2))
# Out:
# Cluster 0 Means:
# birth_rate                          0.16
# business_tax_rate                   2.17
# days_to_start_business             34.54
# energy_usage                        0.80
# gdp                                 1.23
# health_exp_percentage_gdp           0.06
# health_exp/capita                   1.05
# hours_to_do_tax                   260.05
# internet_usage                      0.23
# lending_interest                    0.14
# life_expectancy_female             71.33
# mobile_phone_usage                  0.58
# population_15_64                    0.62
# population_65plus                   0.07
# population_total             12762851.31
# population_urban                    0.56
# Kmeans                              0.00
# heirarchical                        0.00
# dtype: float64
#
# Cluster 1 Means:
# birth_rate                  -1.400000e-01
# business_tax_rate            9.320000e+00
# days_to_start_business       3.923000e+01
# energy_usage                 7.055000e+01
# gdp                          2.678000e+01
# health_exp_percentage_gdp    4.000000e-02
# health_exp/capita           -2.200000e-01
# hours_to_do_tax              3.447700e+02
# internet_usage               1.000000e-01
# lending_interest             9.000000e-02
# life_expectancy_female       7.062000e+01
# mobile_phone_usage           3.200000e-01
# population_15_64             6.700000e-01
# population_65plus            6.000000e-02
# population_total             1.225428e+09
# population_urban             3.700000e-01
# Kmeans                       1.000000e+00
# heirarchical                 1.000000e+00
# dtype: float64
#
# Cluster 2 Means:
# birth_rate                   6.000000e-02
# business_tax_rate            1.380000e+00
# days_to_start_business       4.143000e+01
# energy_usage                 2.712000e+01
# gdp                          2.703000e+01
# health_exp_percentage_gdp    7.000000e-02
# health_exp/capita            2.180000e+00
# hours_to_do_tax              5.074600e+02
# internet_usage               2.500000e-01
# lending_interest             1.500000e-01
# life_expectancy_female       7.201000e+01
# mobile_phone_usage           5.300000e-01
# population_15_64             6.300000e-01
# population_65plus            8.000000e-02
# population_total             1.686685e+08
# population_urban             6.000000e-01
# Kmeans                       2.000000e+00
# heirarchical                 1.920000e+00
# dtype: float64

# %%
data1.head()
# Out:
#    birth_rate  business_tax_rate  days_to_start_business  energy_usage  \
# 0    0.000000                0.0                    26.0      0.810253
# 1    1.764706                0.0                    26.0     -0.437703
# 2    1.352941                0.0                    26.0     -0.790733
# 3    0.411765                0.0                    26.0     -0.800141
# 4    1.529412                0.0                    26.0      0.000000
#
#         gdp  health_exp_percentage_gdp  health_exp/capita  hours_to_do_tax  \
# 0  0.456942                      0.035          -0.269640            239.0
# 1 -0.068468                      0.034          -0.346680            239.0
# 2 -0.146375                      0.043          -0.360872            239.0
# 3 -0.106916                      0.047          -0.083122            239.0
# 4 -0.143477                      0.051          -0.366954            239.0
#
#    internet_usage  lending_interest  life_expectancy_female  \
# 0             0.0             0.100                    71.0
# 1             0.0             1.032                    47.0
# 2             0.0             0.120                    57.0
# 3             0.0             0.155                    52.0
# 4             0.0             0.120                    52.0
#
#    mobile_phone_usage  population_15_64  population_65plus  population_total  \
# 0                 0.0             0.619              0.039          31719449
# 1                 0.0             0.499              0.025          13924930
# 2                 0.0             0.517              0.029           6949366
# 3                 0.1             0.587              0.029           1755375
# 4                 0.0             0.505              0.028          11607944
#
#    population_urban  Kmeans  heirarchical
# 0             0.599       0             0
# 1             0.324       0             0
# 2             0.383       0             0
# 3             0.532       0             0
# 4             0.178       0             0

# %%
cluster_labels = {
    0: 'Emerging & Developing',
    1: 'Developed Superpowers',
    2: 'Least Developed'
}

data2['KMeans_Label'] = data2['Kmeans'].map(cluster_labels)

# %%
data2.head()
# Out:
#             PC1        PC2       PC3       PC4  Kmeans  heirarchical  \
# 0  2.621551e+05 -33.402685 -7.555160 -0.401689       0             0
# 1 -1.753236e+07 -29.751339 -6.719004  5.904484       0             0
# 2 -2.450793e+07 -28.401401 -7.119996  3.242748       0             0
# 3 -2.970192e+07 -27.345357 -6.965251  4.404007       0             0
# 4 -1.984935e+07 -29.310396 -6.922198  4.479500       0             0
#
#             KMeans_Label
# 0  Emerging & Developing
# 1  Emerging & Developing
# 2  Emerging & Developing
# 3  Emerging & Developing
# 4  Emerging & Developing

# %% [markdown]
# #### Model Deployment

# %%
features = ['birth_rate', 'business_tax_rate', 'days_to_start_business',
            'energy_usage', 'gdp', 'health_exp_percentage_gdp',
            'health_exp/capita', 'hours_to_do_tax', 'internet_usage',
            'lending_interest', 'life_expectancy_female',
            'mobile_phone_usage', 'population_15_64', 'population_65plus',
            'population_total', 'population_urban']

X = data[features]

# %%
from sklearn.preprocessing import RobustScaler

scaler = RobustScaler()
X_scaled = scaler.fit_transform(X)

# %%
import pickle

with open('scaler.pkl', 'wb') as f:
    pickle.dump(scaler, f)

# %% [markdown]
# #### Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# %%
lr_model = LogisticRegression(max_iter=1000)
lr_model.fit(X_train, y_train)
# Out:
# LogisticRegression(max_iter=1000)

# %%
y_pred_lr = lr_model.predict(X_train)
lr_accuracy = accuracy_score(y_train, y_pred_lr)
print("Logistic Regression Accuracy:", lr_accuracy)
# Out:
# Logistic Regression Accuracy: 1.0

# %%
y_pred_lr = lr_model.predict(X_test)
lr_accuracy = accuracy_score(y_test, y_pred_lr)
print("Logistic Regression Accuracy:", lr_accuracy)
# Out:
# Logistic Regression Accuracy: 1.0

# %% [markdown]
# #### SVM

# %%
from sklearn.svm import SVC

# %%
svm_model = SVC(kernel='linear')
svm_model.fit(X_train, y_train)
# Out:
# SVC(kernel='linear')

# %%
y_pred_svm = svm_model.predict(X_train)
svm_accuracy = accuracy_score(y_train, y_pred_svm)
print("SVM Accuracy:", svm_accuracy)
# Out:
# SVM Accuracy: 1.0

# %%
y_pred_svm = svm_model.predict(X_test)
svm_accuracy = accuracy_score(y_test, y_pred_svm)
print("SVM Accuracy:", svm_accuracy)
# Out:
# SVM Accuracy: 1.0

# %% [markdown]
# #### Neural Network

# %%
from sklearn.neural_network import MLPClassifier

# %%
nn_model = MLPClassifier(hidden_layer_sizes=(50, 30), max_iter=1000, random_state=42)
nn_model.fit(X_train, y_train)
# Out:
# MLPClassifier(hidden_layer_sizes=(50, 30), max_iter=1000, random_state=42)

# %%
y_pred_nn = nn_model.predict(X_train)
nn_accuracy = accuracy_score(y_train, y_pred_nn)
print("Neural Network Accuracy:", nn_accuracy)
# Out:
# Neural Network Accuracy: 1.0

# %%
with open('svm_model.pkl', 'wb') as f:
    pickle.dump(svm_model, f)

with open('scaler.pkl', 'wb') as f:
    pickle.dump(scaler, f)
